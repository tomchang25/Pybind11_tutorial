# %%
from Game2048 import *

# %%
board = Board()

# %%
while(1):
    if board.game_over():
        print("~~~GAME OVER~~~")
        
    board.display();
    print("Score: ", board.score)
    print("Step: ", board.step)
    
    ch = input()
    
    if ch == 'w':
        board.move_up()
    elif ch == 's':
        board.move_down()
    elif ch == 'a':
        board.move_left()
    elif ch == 'd':
        board.move_right()
# Out:
# |-----------------------|
# |     |     |     |  2  |
# |-----------------------|
# |     |     |     |  2  |
# |-----------------------|
# |     |     |     |     |
# |-----------------------|
# |     |     |     |     |
# |-----------------------|
# Score:  0
# Step:  0
# a
# |-----------------------|
# |  2  |     |     |     |
# |-----------------------|
# |  2  |     |     |     |
# |-----------------------|
# |     |     |     |     |
# |-----------------------|
# |     |     |     |  2  |
# |-----------------------|
# Score:  0
# Step:  1
# s
# |-----------------------|
# |     |     |     |     |
# |-----------------------|
# |     |     |     |  2  |
# |-----------------------|
# |     |     |     |     |
# |-----------------------|
# |  4  |     |     |  2  |
# |-----------------------|
# Score:  4
# Step:  2
# s
# |-----------------------|
# |     |     |     |     |
# |-----------------------|
# |     |     |     |     |
# |-----------------------|
# ...
